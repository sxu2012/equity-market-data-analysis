# %%
#workflow notebook
status = None
status=dbutils.notebook.run('./ingestion', timeout_seconds=60)
if status is None:
    status = 'FAILED'
print('Data Ingestion:'+ status)
print('\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Data Ingestion:SUCCESS
#
#
# </div>

# %%
status = None
status=dbutils.notebook.run('./load', timeout_seconds=60)
if status is None:
    status = 'FAILED'
print('EOD Data Load:'+ status)
print('\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">EOD Data Load:SUCCESS
#
#
# </div>

# %%
status = None
status=dbutils.notebook.run('./analytics', timeout_seconds=60)
if status is None:
    status = 'FAILED'
print('Daily Analytics:'+ status)
print('\n')
print('Equity Market Daily Analysis Complete')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Daily Analytics:SUCCESS
#
#
# Equity Market Daily Analysis Complete
# </div>
